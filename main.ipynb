# %%
from ultralytics import YOLO
import cv2

# %%
model = YOLO("my_model.pt")

# %%
cap = cv2.VideoCapture(0) 

while True:
    
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, show=False, conf=0.6)  

    
    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])  
            cls_id = int(box.cls[0])                
            conf = float(box.conf[0])               
            label = model.names[cls_id]             
           
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label} ({conf:.2f})", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    
    cv2.imshow("Potato Detector", frame)

    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Step 7: Release and close
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 2 Defectives, 524.5ms
# Speed: 12.9ms preprocess, 524.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 479.2ms
# Speed: 5.9ms preprocess, 479.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 414.9ms
# Speed: 6.0ms preprocess, 414.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 391.4ms
# Speed: 4.3ms preprocess, 391.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 376.4ms
# Speed: 5.9ms preprocess, 376.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 357.4ms
# Speed: 4.7ms preprocess, 357.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 386.7ms
# Speed: 4.2ms preprocess, 386.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Defectives, 384.7ms
# ...

# %%
import cv2
from ultralytics import YOLO

# Load your YOLO model
model = YOLO("my_model.pt")


ip_camera_url = "http://192.168.8.100:8080/video"  
cap = cv2.VideoCapture(ip_camera_url)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(source=frame, show=False, conf=0.6)

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls_id = int(box.cls[0])
            conf = float(box.conf[0])
            label = model.names[cls_id]

            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(frame, f"{label} ({conf:.2f})", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    # Show the annotated frame
    cv2.imshow("Potato Detector", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release everything
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Defective, 723.5ms
# Speed: 25.1ms preprocess, 723.5ms inference, 19.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Defective, 1 Good, 400.4ms
# Speed: 9.5ms preprocess, 400.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Defectives, 391.0ms
# Speed: 7.3ms preprocess, 391.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Defectives, 398.0ms
# Speed: 7.2ms preprocess, 398.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 Defectives, 479.9ms
# Speed: 8.3ms preprocess, 479.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 Defectives, 448.9ms
# Speed: 12.0ms preprocess, 448.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 Defectives, 367.3ms
# Speed: 8.0ms preprocess, 367.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
